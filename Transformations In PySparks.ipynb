# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

emp_data = [
    (1, "John", 30, 1000, 101),
    (2, "Alice", 25, 1500, 102),
    (3, "Bob", 35, 2000, 103),
    (4, "David", 40, 2500, 101),
    (5, "Eva", 28, 1200, 104),
    (6, "Mike", 45, 3000, 102),
    (7, "Sophia", 33, 1800, 103),
    (8, "Sam", 29, 2200, 101),
    (9, "Rose", 31, 1700, 102),
    (10, "Chris", 26, 1300, 104),
    (11, "Liam", 37, 2600, 103),
    (12, "Emma", 24, 1400, 102),
    (13, "Noah", 50, 3200, 101),
    (14, "Olivia", 27, 1900, 103),
    (15, "James", 41, 2800, 104),
    (16, "Mia", 36, 2100, 102),
    (17, "Lucas", 32, 2300, 101),
    (18, "Isabella", 29, 1950, 103),
    (19, "Mason", 39, 3100, 104),
    (20, "Sophia", 34, 1700, 102),
    (21, "Benjamin", 38, 2900, 101),
    (22, "Charlotte", 42, 2750, 104),
    (23, "Elijah", 44, 3000, 103),
    (24, "Amelia", 23, 1600, 101),
    (25, "William", 49, 3400, 104),
    (26, "Harper", 28, 2200, 102),
    (27, "Ethan", 31, 1800, 103),
    (28, "Abigail", 29, 2150, 101),
    (29, "Henry", 33, 2050, 104),
    (30, "Ava", 35, 1900, 102),
    (31, "Alexander", 43, 3100, 103),
    (32, "Ella", 27, 2000, 101),
    (33, "Sebastian", 46, 3300, 104),
    (34, "Avery", 22, 1200, 102),
    (35, "Matthew", 38, 2500, 103),
    (36, "Scarlett", 30, 1700, 101),
    (37, "Levi", 29, 2000, 104),
    (38, "Victoria", 34, 2300, 102),
    (39, "Logan", 31, 2100, 103),
    (40, "Emily", 28, 1800, 101),
    (41, "Daniel", 40, 2800, 102),
    (42, "Grace", 36, 2200, 103),
    (43, "Owen", 35, 1900, 104),
    (44, "Chloe", 30, 1600, 101),
    (45, "Luke", 41, 3000, 103),
    (46, "Lily", 24, 1500, 102),
    (47, "Julian", 39, 2700, 104),
    (48, "Hannah", 32, 1900, 101),
    (49, "Jack", 44, 3100, 102),
    (50, "Ellie", 26, 1300, 103),
    (51, "Samuel", 47, 3500, 101),
    (52, "Zoe", 25, 1400, 104),
    (53, "Isaac", 34, 2000, 102),
    (54, "Aria", 33, 1700, 103),
    (55, "Carter", 40, 2800, 101),
    (56, "Layla", 31, 1500, 104),
    (57, "Wyatt", 38, 2600, 102),
    (58, "Lillian", 30, 1800, 103),
    (59, "Nathan", 42, 2900, 101),
    (60, "Penelope", 29, 2100, 104),
    (61, "Isaiah", 28, 1900, 102),
    (62, "Addison", 27, 2000, 103),
    (63, "Gabriel", 43, 3200, 101),
    (64, "Savannah", 36, 2300, 104),
    (65, "Anthony", 39, 3000, 102),
    (66, "Violet", 24, 1500, 103),
    (67, "Dylan", 45, 3100, 101),
    (68, "Stella", 23, 1400, 104),
    (69, "Thomas", 37, 2400, 102),
    (70, "Aurora", 31, 2200, 103),
    (71, "Jaxon", 33, 1800, 101),
    (72, "Aubrey", 29, 1950, 104),
    (73, "Grayson", 30, 1700, 102),
    (74, "Zoey", 34, 2000, 103),
    (75, "Isaac", 48, 3200, 101),
    (76, "Sofia", 27, 1600, 104),
    (77, "Christian", 41, 2800, 102),
    (78, "Skylar", 25, 1700, 103),
    (79, "Hunter", 31, 2300, 101),
    (80, "Brooklyn", 28, 2000, 104),
    (81, "Mason", 37, 2900, 102),
    (82, "Camila", 30, 1500, 103),
    (83, "Eli", 40, 3100, 101),
    (84, "Riley", 29, 2200, 104),
    (85, "Easton", 44, 3200, 102),
    (86, "Paisley", 23, 1200, 103),
    (87, "Aaron", 47, 3000, 101),
    (88, "Hazel", 32, 1900, 104),
    (89, "Adrian", 34, 2300, 102),
    (90, "Elliana", 27, 1800, 103),
    (91, "Joshua", 43, 2700, 101),
    (92, "Audrey", 26, 1500, 104),
    (93, "Adam", 35, 2500, 102),
    (94, "Bella", 33, 1700, 103),
    (95, "Andrew", 41, 2800, 101),
    (96, "Eva", 28, 1200, 104),
    (97, "Jonathan", 36, 2400, 102),
    (98, "Clara", 25, 1400, 103),
    (99, "Nathaniel", 38, 2900, 101),
    (100, "Ruby", 29, 1600, 104),
]
emp_schema = ["EmployeId","Name","Age","Salary","DepartmentId"]
emp_df = spark.createDataFrame(data=emp_data,schema=emp_schema)
emp_df.createOrReplaceTempView("temp_emp_df_view")
emp_df.show()
# Out:
# +---------+--------+---+------+------------+
# |EmployeId|    Name|Age|Salary|DepartmentId|
# +---------+--------+---+------+------------+
# |        1|    John| 30|  1000|         101|
# |        2|   Alice| 25|  1500|         102|
# |        3|     Bob| 35|  2000|         103|
# |        4|   David| 40|  2500|         101|
# |        5|     Eva| 28|  1200|         104|
# |        6|    Mike| 45|  3000|         102|
# |        7|  Sophia| 33|  1800|         103|
# |        8|     Sam| 29|  2200|         101|
# |        9|    Rose| 31|  1700|         102|
# |       10|   Chris| 26|  1300|         104|
# |       11|    Liam| 37|  2600|         103|
# |       12|    Emma| 24|  1400|         102|
# |       13|    Noah| 50|  3200|         101|
# |       14|  Olivia| 27|  1900|         103|
# |       15|   James| 41|  2800|         104|
# |       16|     Mia| 36|  2100|         102|
# |       17|   Lucas| 32|  2300|         101|
# |       18|Isabella| 29|  1950|         103|
# ...

# %%
# Aliasing
emp_df.select(col("EmployeId").alias("id"), "name", "age").show()
# Out:
# +---+--------+---+
# | id|    name|age|
# +---+--------+---+
# |  1|    John| 30|
# |  2|   Alice| 25|
# |  3|     Bob| 35|
# |  4|   David| 40|
# |  5|     Eva| 28|
# |  6|    Mike| 45|
# |  7|  Sophia| 33|
# |  8|     Sam| 29|
# |  9|    Rose| 31|
# | 10|   Chris| 26|
# | 11|    Liam| 37|
# | 12|    Emma| 24|
# | 13|    Noah| 50|
# | 14|  Olivia| 27|
# | 15|   James| 41|
# | 16|     Mia| 36|
# | 17|   Lucas| 32|
# | 18|Isabella| 29|
# | 19|   Mason| 39|
# | 20|  Sophia| 34|
# +---+--------+---+
# only showing top 20 rows

# %%
# Use of filter/where and applied multiple conditions - filter and where both are same.

emp_df.filter((col("salary")>1000) & (col("age")<30)).show()
# Out:
# +---------+--------+---+------+------------+
# |EmployeId|    Name|Age|Salary|DepartmentId|
# +---------+--------+---+------+------------+
# |        2|   Alice| 25|  1500|         102|
# |        5|     Eva| 28|  1200|         104|
# |        8|     Sam| 29|  2200|         101|
# |       10|   Chris| 26|  1300|         104|
# |       12|    Emma| 24|  1400|         102|
# |       14|  Olivia| 27|  1900|         103|
# |       18|Isabella| 29|  1950|         103|
# |       24|  Amelia| 23|  1600|         101|
# |       26|  Harper| 28|  2200|         102|
# |       28| Abigail| 29|  2150|         101|
# |       32|    Ella| 27|  2000|         101|
# |       34|   Avery| 22|  1200|         102|
# |       37|    Levi| 29|  2000|         104|
# |       40|   Emily| 28|  1800|         101|
# |       46|    Lily| 24|  1500|         102|
# |       50|   Ellie| 26|  1300|         103|
# |       52|     Zoe| 25|  1400|         104|
# |       60|Penelope| 29|  2100|         104|
# ...

# %%
# use of literals
emp_df.select("*", lit("kumar").alias("last_name")).show()
# Out:
# +---------+--------+---+------+------------+---------+
# |EmployeId|    Name|Age|Salary|DepartmentId|last_name|
# +---------+--------+---+------+------------+---------+
# |        1|    John| 30|  1000|         101|    kumar|
# |        2|   Alice| 25|  1500|         102|    kumar|
# |        3|     Bob| 35|  2000|         103|    kumar|
# |        4|   David| 40|  2500|         101|    kumar|
# |        5|     Eva| 28|  1200|         104|    kumar|
# |        6|    Mike| 45|  3000|         102|    kumar|
# |        7|  Sophia| 33|  1800|         103|    kumar|
# |        8|     Sam| 29|  2200|         101|    kumar|
# |        9|    Rose| 31|  1700|         102|    kumar|
# |       10|   Chris| 26|  1300|         104|    kumar|
# |       11|    Liam| 37|  2600|         103|    kumar|
# |       12|    Emma| 24|  1400|         102|    kumar|
# |       13|    Noah| 50|  3200|         101|    kumar|
# |       14|  Olivia| 27|  1900|         103|    kumar|
# ...

# %%
# creating new column using withColumn funtion
emp_df.withColumn("sur_name", lit("singh")).show()
# Out:
# +---------+--------+---+------+------------+--------+
# |EmployeId|    Name|Age|Salary|DepartmentId|sur_name|
# +---------+--------+---+------+------------+--------+
# |        1|    John| 30|  1000|         101|   singh|
# |        2|   Alice| 25|  1500|         102|   singh|
# |        3|     Bob| 35|  2000|         103|   singh|
# |        4|   David| 40|  2500|         101|   singh|
# |        5|     Eva| 28|  1200|         104|   singh|
# |        6|    Mike| 45|  3000|         102|   singh|
# |        7|  Sophia| 33|  1800|         103|   singh|
# |        8|     Sam| 29|  2200|         101|   singh|
# |        9|    Rose| 31|  1700|         102|   singh|
# |       10|   Chris| 26|  1300|         104|   singh|
# |       11|    Liam| 37|  2600|         103|   singh|
# |       12|    Emma| 24|  1400|         102|   singh|
# |       13|    Noah| 50|  3200|         101|   singh|
# |       14|  Olivia| 27|  1900|         103|   singh|
# ...

# %%
# renaming column using withcolumnRenamed funtion
emp_df.withColumnRenamed("Name","Emp_name").show()
# Out:
# +---------+--------+---+------+------------+
# |EmployeId|Emp_name|Age|Salary|DepartmentId|
# +---------+--------+---+------+------------+
# |        1|    John| 30|  1000|         101|
# |        2|   Alice| 25|  1500|         102|
# |        3|     Bob| 35|  2000|         103|
# |        4|   David| 40|  2500|         101|
# |        5|     Eva| 28|  1200|         104|
# |        6|    Mike| 45|  3000|         102|
# |        7|  Sophia| 33|  1800|         103|
# |        8|     Sam| 29|  2200|         101|
# |        9|    Rose| 31|  1700|         102|
# |       10|   Chris| 26|  1300|         104|
# |       11|    Liam| 37|  2600|         103|
# |       12|    Emma| 24|  1400|         102|
# |       13|    Noah| 50|  3200|         101|
# |       14|  Olivia| 27|  1900|         103|
# |       15|   James| 41|  2800|         104|
# |       16|     Mia| 36|  2100|         102|
# |       17|   Lucas| 32|  2300|         101|
# |       18|Isabella| 29|  1950|         103|
# ...

# %%
# Suppose I want to save my updated dataframe and use it as a new df then
updated_emp_df = emp_df.withColumnRenamed("Name","Emp_name")

# %%
updated_emp_df.show()
# Out:
# +---------+--------+---+------+------------+
# |EmployeId|Emp_name|Age|Salary|DepartmentId|
# +---------+--------+---+------+------------+
# |        1|    John| 30|  1000|         101|
# |        2|   Alice| 25|  1500|         102|
# |        3|     Bob| 35|  2000|         103|
# |        4|   David| 40|  2500|         101|
# |        5|     Eva| 28|  1200|         104|
# |        6|    Mike| 45|  3000|         102|
# |        7|  Sophia| 33|  1800|         103|
# |        8|     Sam| 29|  2200|         101|
# |        9|    Rose| 31|  1700|         102|
# |       10|   Chris| 26|  1300|         104|
# |       11|    Liam| 37|  2600|         103|
# |       12|    Emma| 24|  1400|         102|
# |       13|    Noah| 50|  3200|         101|
# |       14|  Olivia| 27|  1900|         103|
# |       15|   James| 41|  2800|         104|
# |       16|     Mia| 36|  2100|         102|
# |       17|   Lucas| 32|  2300|         101|
# |       18|Isabella| 29|  1950|         103|
# ...

# %%
# casting the type of column to some other type
updated_emp_df.printSchema()
# Out:
# root
#  |-- EmployeId: long (nullable = true)
#  |-- Emp_name: string (nullable = true)
#  |-- Age: long (nullable = true)
#  |-- Salary: long (nullable = true)
#  |-- DepartmentId: long (nullable = true)

# %%
updated_emp_df.withColumn("EmployeId",col("EmployeId").cast("string"))\
                .withColumn("salary",col("salary").cast("double"))\
            .printSchema()
# Out:
# root
#  |-- EmployeId: string (nullable = true)
#  |-- Emp_name: string (nullable = true)
#  |-- Age: long (nullable = true)
#  |-- salary: double (nullable = true)
#  |-- DepartmentId: long (nullable = true)

# %%
# remove column using drop functions
updated_emp_df.drop(col("EmployeId")).show()
# Out:
# +--------+---+------+------------+
# |Emp_name|Age|Salary|DepartmentId|
# +--------+---+------+------------+
# |    John| 30|  1000|         101|
# |   Alice| 25|  1500|         102|
# |     Bob| 35|  2000|         103|
# |   David| 40|  2500|         101|
# |     Eva| 28|  1200|         104|
# |    Mike| 45|  3000|         102|
# |  Sophia| 33|  1800|         103|
# |     Sam| 29|  2200|         101|
# |    Rose| 31|  1700|         102|
# |   Chris| 26|  1300|         104|
# |    Liam| 37|  2600|         103|
# |    Emma| 24|  1400|         102|
# |    Noah| 50|  3200|         101|
# |  Olivia| 27|  1900|         103|
# |   James| 41|  2800|         104|
# |     Mia| 36|  2100|         102|
# |   Lucas| 32|  2300|         101|
# |Isabella| 29|  1950|         103|
# |   Mason| 39|  3100|         104|
# |  Sophia| 34|  1700|         102|
# +--------+---+------+------------+
# only showing top 20 rows

# %%
spark.sql("""
                         
                         select * from temp_emp_df_view where Age>30 and Salary>1000
                         
                         
                         """).show()
# Out:
# +---------+---------+---+------+------------+
# |EmployeId|     Name|Age|Salary|DepartmentId|
# +---------+---------+---+------+------------+
# |        3|      Bob| 35|  2000|         103|
# |        4|    David| 40|  2500|         101|
# |        6|     Mike| 45|  3000|         102|
# |        7|   Sophia| 33|  1800|         103|
# |        9|     Rose| 31|  1700|         102|
# |       11|     Liam| 37|  2600|         103|
# |       13|     Noah| 50|  3200|         101|
# |       15|    James| 41|  2800|         104|
# |       16|      Mia| 36|  2100|         102|
# |       17|    Lucas| 32|  2300|         101|
# |       19|    Mason| 39|  3100|         104|
# |       20|   Sophia| 34|  1700|         102|
# |       21| Benjamin| 38|  2900|         101|
# |       22|Charlotte| 42|  2750|         104|
# |       23|   Elijah| 44|  3000|         103|
# |       25|  William| 49|  3400|         104|
# |       27|    Ethan| 31|  1800|         103|
# ...
